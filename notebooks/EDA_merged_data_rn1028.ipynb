# %% [markdown]
# # EDA for combined data
#
# This notebooks contains the first round of EDA for the combined data set.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bee_df=pd.read_csv=("../data/interim/combined_nass_aphis_weather_1028_df.csv")

# %%
bee_df['bip_loss_higher'] = (bee_df['bip_loss'] > bee_df['bip_loss_prev5yrs']).astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 bee_df['bip_loss_higher'] = (bee_df['bip_loss'] > bee_df['bip_loss_prev5yrs']).astype(int)
#
# TypeError: string indices must be integers, not 'str'

# %%
type(bee_df)
# Out:
# str
