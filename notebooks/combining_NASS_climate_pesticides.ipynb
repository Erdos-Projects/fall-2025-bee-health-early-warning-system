# %% [markdown]
# First we need to combine the NASS data set, the pesticide use and the weather data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bee_df = pd.read_csv("../data/interim/bee_df.csv")
clim_df = pd.read_csv("../data/raw/NOAA_weather_data/normalized_weather_data.csv")
pest_df = pd.read_csv("../data/raw/Pesticide datasets/aggregated_pesticide_use_1992-2019.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 bee_df = pd.read_csv("../data/interim/bee_df.csv")
#       2 clim_df = pd.read_csv("../data/raw/NOAA_weather_data/normalized_weather_data.csv")
#       3 pest_df = pd.read_csv("../data/raw/Pesticide datasets/aggregated_pesticide_use_1992-2019.csv")
#
# ...

# %%
clim_df.head
# Out:
# <bound method NDFrame.head of       ID_state  ID_year Quarter         cddc         hddc      pcpn      pdsi  \
# 0            1     2015      Q1    13.666667   564.666667  4.223333 -0.870000
# 1            1     2015      Q2   234.666667    31.333333  4.910000 -0.750000
# 2            1     2015      Q3   396.000000     1.666667  4.120000 -1.183333
# 3            1     2015      Q4    51.000000   211.333333  7.200000  0.590000
# 4            1     2016      Q1    20.000000   469.000000  5.110000 -0.280000
# ...        ...      ...     ...          ...          ...       ...       ...
# 2195        50     2024      Q4 -9999.000000 -9999.000000  3.040000       NaN
# 2196        50     2025      Q1 -9999.000000 -9999.000000  2.603333       NaN
# 2197        50     2025      Q2 -9999.000000 -9999.000000  2.900000       NaN
# 2198        50     2025      Q3 -9999.000000 -9999.000000 -0.970000       NaN
# 2199        50     2025      Q4 -9999.000000 -9999.000000 -9.990000       NaN
#
# ...
